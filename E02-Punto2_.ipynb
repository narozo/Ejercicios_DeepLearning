# %% [markdown]
# CAMILO E. PRADA LADINO 201021153
#  NELSON A. ROZO CRUZ 201728031
#
#
# # Exercise 02
#
# Estimate a regression using the Income data
#
#
# ## Forecast of income
#
# We'll be working with a dataset from US Census indome ([data dictionary](https://archive.ics.uci.edu/ml/datasets/Adult)).
#
# Many businesses would like to personalize their offer based on customer’s income. High-income customers could be, for instance, exposed to premium products. As a customer’s income is not always explicitly known, predictive model could estimate income of a person based on other information.
#
# Our goal is to create a predictive model that will be able to output an estimation of a person income.

# %%
import pandas as pd
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt

# read the data and set the datetime as the index
import zipfile
with zipfile.ZipFile('D:\Talleres DL/income.csv.zip', 'r') as z:
    f = z.open('income.csv')
    income = pd.read_csv(f, index_col=0)

income.head()
# Out:
#    Age         Workclass  fnlwgt  Education  Education-Num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        Martial Status         Occupation   Relationship   Race     Sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    Capital Gain  Capital Loss  Hours per week        Country   Income
# 0          2174             0              40  United-States  51806.0
# ...

# %%
income.keys()
# Out:
# Index(['Age', 'Workclass', 'fnlwgt', 'Education', 'Education-Num',
#        'Martial Status', 'Occupation', 'Relationship', 'Race', 'Sex',
#        'Capital Gain', 'Capital Loss', 'Hours per week', 'Country', 'Income'],
#       dtype='object')

# %%
income.keys()
# Out:
# Index(['Age', 'Workclass', 'fnlwgt', 'Education', 'Education-Num',
#        'Martial Status', 'Occupation', 'Relationship', 'Race', 'Sex',
#        'Capital Gain', 'Capital Loss', 'Hours per week', 'Country', 'Income'],
#       dtype='object')

# %% [markdown]
# # Exercise 2.1
#
# What is the relation between the age and Income?
#
# For a one percent increase in the Age how much the income increases?
#
# Using sklearn estimate a linear regression and predict the income when the Age is 30 and 40 years

# %%
income.plot(x='Age', y='Income', kind='scatter')

# %%
# importar
from sklearn.linear_model import LinearRegression

# %%
# Inicio
rl = LinearRegression(fit_intercept=True)

# %%
y = income['Income'].values.reshape(-1,1)
X = income['Age'].values.reshape(-1,1)

# %%
X.shape
# Out:
# (32561, 1)

# %%
# Fit (Modelo Supervisado)
rl.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
rl.coef_
# Out:
# array([[542.16765707]])

# %% [markdown]
# # Respuesta
#
# **1**. No hay evidencia suficiente en el gráfico para concluir que hay una relación entre la edad y el ingreso.
#
# **2**. El aumento en una unidad porcentual en la edad se traduce en un aumento del ingreso de US$542.17.

# %% [markdown]
# # Exercise 2.2
# Evaluate the model using the MSE

# %%
# Se trae la libreria para calcular el MSE
from sklearn import metrics
# También importamos de sklearn la función para realizar la partición de los datos y correr un modelo
# con set de train y evaluarlo con el test
from sklearn.model_selection import train_test_split

# %%
# Se parte la base en train y test
X_train, X_test, y_train, y_test=train_test_split(X, y)

# %%
# Ajuste del modelo
rl.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# Evaluación del modelo
rl.score(X_test, y_test)
# Out:
# 0.08470902131051639

# %%
# Se estima la predicción
y_pred = rl.predict(income[['Age']])

# %%
#Calculo del MSE
print('MSE:', metrics.mean_squared_error(income['Income'], y_pred))
# Out:
# MSE: 593785537.4001554

# %% [markdown]
# # Exercise 2.3
#
# Run a regression model using as features the Age and Age$^2$ using the OLS equations

# %%
# Modelo utilizando OLS equations
beta = np.dot(np.linalg.inv(np.dot(X.T, X)),np.dot(X.T, y))

# %%
beta
# Out:
# array([[1291.82348999]])

# %%
# Generación de variable age^2
income['Age2'] = income['Age'] ** 2
income
# Out:
#        Age         Workclass  fnlwgt     Education  Education-Num  \
# 0       39         State-gov   77516     Bachelors             13
# 1       50  Self-emp-not-inc   83311     Bachelors             13
# 2       38           Private  215646       HS-grad              9
# 3       53           Private  234721          11th              7
# 4       28           Private  338409     Bachelors             13
# 5       37           Private  284582       Masters             14
# 6       49           Private  160187           9th              5
# 7       52  Self-emp-not-inc  209642       HS-grad              9
# 8       31           Private   45781       Masters             14
# 9       42           Private  159449     Bachelors             13
# 10      37           Private  280464  Some-college             10
# 11      30         State-gov  141297     Bachelors             13
# 12      23           Private  122272     Bachelors             13
# ...

# %%
# Selección de las variables para la predicción
y = income['Income'].values.reshape(-1,1)
XX = income[['Age', 'Age2']] 

print(XX)
# Out:
#        Age  Age2
# 0       39  1521
# 1       50  2500
# 2       38  1444
# 3       53  2809
# 4       28   784
# 5       37  1369
# 6       49  2401
# 7       52  2704
# 8       31   961
# 9       42  1764
# 10      37  1369
# 11      30   900
# 12      23   529
# 13      32  1024
# 14      40  1600
# 15      34  1156
# 16      25   625
# 17      32  1024
# 18      38  1444
# 19      43  1849
# 20      40  1600
# 21      54  2916
# 22      35  1225
# 23      43  1849
# 24      59  3481
# 25      56  3136
# 26      19   361
# 27      54  2916
# 28      39  1521
# 29      49  2401
# ...    ...   ...
# 32531   30   900
# 32532   34  1156
# 32533   54  2916
# 32534   37  1369
# 32535   22   484
# 32536   34  1156
# 32537   30   900
# 32538   38  1444
# 32539   71  5041
# 32540   45  2025
# 32541   41  1681
# 32542   72  5184
# 32543   45  2025
# 32544   31   961
# 32545   39  1521
# 32546   37  1369
# 32547   43  1849
# 32548   65  4225
# 32549   43  1849
# 32550   43  1849
# ...

# %%
#Tamaño de las matrices generadas
y.shape
#(32561L, 1L)
XX.shape
#(32561, 2)
# Out:
# (32561, 2)

# %%
# Iniciar
rl2 = LinearRegression(fit_intercept=True)

# %%
# generación del segundo modelo
rl2.fit(XX, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
rl2.coef_
# Out:
# array([[3131.77014151,  -30.54341041]])

# %% [markdown]
# # Exercise 2.4
#
#
# Estimate a regression using more features.
#
# How is the performance compared to using only the Age?

# %%
X_X = income[['Age', 'Age2', 'Education-Num', 'Hours per week']]

# %%
# Se parte la base en train y test
X_Xtrain, X_Xtest, y_y_train, y_y_test=train_test_split(X_X, y)

# %%
# Inicio
rl3 = LinearRegression(fit_intercept=True)

# %%
rl3.fit(X_X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# Evaluación del modelo
rl3.score(X_Xtest, y_y_test)
# Out:
# 0.3222501434881765

# %%
# El score es mejor para este modelo que para el inicial

# %% [markdown]
# # Resultados
#
# Con base en el score del segundo modelo, se puede concluir que con la inclusión de nuevas variables se mejora la predicción con respecto al primero

# %% [markdown]
# # Exercise 2.5|
#
#
# Estimate a logistic regression to predict if a person is in the United States.
#
# What is the performance of the model

# %%
# Carga de libreria
from sklearn.linear_model import LinearRegression
log = LinearRegression()
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Creación de variable a predecir
income['isUS'] = (income['Country'] == 'United-States')*1.0
income['isUS'].value_counts()
# Out:
# 1.0    29170
# 0.0     3391
# Name: isUS, dtype: int64

# %%
income.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32561 entries, 0 to 32560
# Data columns (total 17 columns):
# Age               32561 non-null int64
# Workclass         30725 non-null object
# fnlwgt            32561 non-null int64
# Education         32561 non-null object
# Education-Num     32561 non-null int64
# Martial Status    32561 non-null object
# Occupation        30718 non-null object
# Relationship      32561 non-null object
# Race              32561 non-null object
# Sex               32561 non-null object
# Capital Gain      32561 non-null int64
# Capital Loss      32561 non-null int64
# Hours per week    32561 non-null int64
# Country           31978 non-null object
# Income            32561 non-null float64
# Age2              32561 non-null int64
# isUS              32561 non-null float64
# dtypes: float64(2), int64(7), object(8)
# memory usage: 5.7+ MB

# %%
del income ['Country']

# %%
income1 = pd.get_dummies(income)

# %%
income1.head()
# Out:
#    Age  fnlwgt  Education-Num  Capital Gain  Capital Loss  Hours per week  \
# 0   39   77516             13          2174             0              40
# 1   50   83311             13             0             0              13
# 2   38  215646              9             0             0              40
# 3   53  234721              7             0             0              40
# 4   28  338409             13             0             0              40
#
#     Income  Age2  isUS  Workclass_Federal-gov    ...     \
# 0  51806.0  1521   1.0                      0    ...
# 1  68719.0  2500   1.0                      0    ...
# 2  51255.0  1444   1.0                      0    ...
# 3  47398.0  2809   1.0                      0    ...
# 4  30493.0   784   0.0                      0    ...
#
#    Relationship_Own-child  Relationship_Unmarried  Relationship_Wife  \
# 0                       0                       0                  0
# ...

# %%
# Generar variable de genero (sex) Binaria
income['sex'] = (income['Sex'] == 'Male')*1.0
income['sex'].value_counts()
# Out:
# 1.0    21790
# 0.0    10771
# Name: sex, dtype: int64

# %%
# Selección de variables predictoras de la logistica
XX = income[['Age', 'Age2', 'Education-Num', 'Hours per week','sex']]

# %%
income1.head(10)
# Out:
#    Age  fnlwgt  Education-Num  Capital Gain  Capital Loss  Hours per week  \
# 0   39   77516             13          2174             0              40
# 1   50   83311             13             0             0              13
# 2   38  215646              9             0             0              40
# 3   53  234721              7             0             0              40
# 4   28  338409             13             0             0              40
# 5   37  284582             14             0             0              40
# 6   49  160187              5             0             0              16
# 7   52  209642              9             0             0              45
# 8   31   45781             14         14084             0              50
# 9   42  159449             13          5178             0              40
#
#      Income  Age2  isUS  Workclass_Federal-gov    ...     \
# 0   51806.0  1521   1.0                      0    ...
# ...

# %%
Y = income['isUS'].values.reshape(-1,1)

# %%
log.fit(XX,Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print log.score(XX, Y)
# Out:
#   File "<ipython-input-47-544b07e3fdd7>", line 1
#     print log.score(XX, Y)
#             ^
# SyntaxError: invalid syntax
